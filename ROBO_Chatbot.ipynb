# %%
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 981 kB 5.1 MB/s
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=56c24e4635ac9761fbab7e8698cb49be42db7aa0c898c98e0889d137c466c03f
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
# Successfully built langdetect
# ...

# %%
# !pip install google_trans_new
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import json
import string
import random 
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer 
import tensorflow as tensorF
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
ourData = {
  "intents": [
    {
      "tag": "greeting",
      "patterns": [
        "Hi",
        "Hello,",
        "do you offer data science course"
      ],
      "responses": [
        "Hello,",
        "Hi there, what can I do for you?",
        "Hi there, how can I help?",
        "Yes, we do!"
      ]
    },
    {
     "tag":"data science",
     "patterns":["do you have data science course",
               "data science course ?"],
     "responses":["Yes,we do!"]
    },
    {
      "tag": "goodbye",
      "patterns": ["Bye", "See you later", "Goodbye"],
      "responses": [
        "See you later, thanks for visiting",
        "Have a nice day",
        "Bye! Come back again soon."
      ]
    },
    {
      "tag": "thanks",
      "patterns": ["Thanks", "Thank you", "That's helpful", "Thank's a lot!"],
      "responses": ["Happy to help!", "Any time!", "My pleasure"]
    },
    {
      "tag": "courses",
      "patterns": [
        "what all courses do you have?",
        "how many courses?"
        "I would like to enquire about data science courses here.",
        "I would like to ask about data science courses here.",
        "I would like to know about data science courses here.",
        "data science courses here."
      ],
      "responses": [
        "We provide classes for Python, SQL, Machine Learning, Deep Learning, Natural Language Processing,Data science"
      ]
    },
    {
      "tag": "capstone project",
      "patterns": [
        "what is capstone project ?",
        "capdtone project ?",
        "tell me about capstone project ?"
      ],
      "responses": [
        "It's a project that you have to undertake at the end of your course."
      ]
    }, 
    {
      "tag": "nlp",
      "patterns": [
        "what is nlp ?",
        "nlp ?",
        "tell me about nlp ?"
      ],
      "responses": [
        "It is Natural Language Processing"
      ]
    }, 
    {
      "tag": "okay",
      "patterns": [
        "okay",
        "okay thanks"
      ],
      "responses": [
        "anything else?"
      ]
    }, 
     {
      "tag": "fine",
      "patterns": [
        "How are you?"
    
      ],
      "responses": [
        "I'm good",
        "good,thanks for asking"
      ]
    }, 
     {
      "tag": "Placements",
      "patterns": [
        "what about placements ?",
        "do you offer placements ?"
      ],
      "responses": [
        "Yes. we carry forward an experience in IT training since 22 years. \nBook my show's first employee was our student.\nwe have recently places students ini MNC's like name etc. "
      ]
    }, 
      
    {
      "tag": "duration of course",
      "patterns": [
        "how much time will it take to finish the course ?",
        "what is the duration of the course ?",
        "how long will it take to finish the course ?"
      ],
      "responses": [
        "It take around 2-3 months to complete the each course and the duration of full data science course is approx 10-12 months which inculdes capstone project"
      ]
    },
    {
      "tag": "class",
      "patterns": [
        "when is the class ?",
        "is the class daily ?",
        "do we need to come for class every day ?"
      ],
      "responses": [
        "the classes are conducted thrice a week. Either MWF or TTS"
      ]
    },
    {
      "tag": "Fees",
      "patterns": [
        "What is the fees of the course ?",
        "fees of the course ?",
        "fees ?"
      ],
      "responses": [
        "It depends on whether you are doing Data Engineering(data Analytics)/or Machine Learning(ML) or the entire Data Science with deep Learning and NLP"
      ]
    },
     {
      "tag": "placement guarantee",
      "patterns": [
        "do you have placement gurantee?",
        "what is placement gurantee ?",
        "placement guarantee ?",
        "is there placement gurantee ?"
      ],
      "responses": [
        "The gurantee is foe interviews with companies. Ultimately you have to answer to question"
      ]
    }, 
     {
      "tag": "preplacement sessions",
      "patterns": [
        "what is about placement preparation sessions ?",
        "placement preparation sessions ?",
          ],
      "responses": [
        "Yes there are session form personality developement to soft skills training etc."
      ]
    }, 
    {
      "tag": "duration of class",
      "patterns": [
        "how long is one session for ?",
        "how long does one class go on for ?",
        "how long is one class ?",
        "what is the duration of one class ?"

      ],
      "responses": [
        "the duration of one class is 2 hours."
      ]
    }
  ]
}

# %%
hiData = {
  "intents": [
    {
      "tag": "शुभकामना",
      "patterns": [
        "हाय",
        "नमस्ते,",
        "क्या आप डेटा विज्ञान पाठ्यक्रम प्रदान करते हैं"
      ],
      "responses": [
        "नमस्ते,",
        "हाय वहाँ, मैं तुम्हारे लिए क्या कर सकता हूँ?",
        "हाय वहाँ, मैं कैसे मदद कर सकता हूँ?",
        "हाँ हम करते हैं!"
      ]
    },
    {
     "tag":"डेटा विज्ञान",
     "patterns":["क्या आपके पास डेटा साइंस कोर्स है",
               "डेटा साइंस कोर्स?"],
     "responses":["हाँ हम करते हैं!"]
    },
    {
      "tag": "अलविदा",
      "patterns": ["अलविदा", "बाद में मिलते हैं", "अलविदा"],
      "responses": [
        "बाद में मिलते हैं, आने के लिए धन्यवाद",
        "आपका दिन शुभ हो",
        "अलविदा! फिर से जल्दी आओ।"
      ]
    },
    {
      "tag": "धन्यवाद",
      "patterns": ["धन्यवाद", "धन्यवाद", "यह मददगार है", "बहुत-बहुत धन्यवाद!"],
      "responses": ["मदद करने में खुशी होगी!", "किसी भी समय!", "मेरा सौभाग्य"]
    },
    {
      "tag": "पाठ्यक्रम",
      "patterns": [
        "आपके पास कौन से कोर्स हैं?",
        "कितने कोर्स?"
        "मैं यहां डेटा साइंस कोर्स के बारे में पूछताछ करना चाहता हूं।",
        "मैं यहां डेटा साइंस कोर्स के बारे में पूछना चाहता हूं।",
        "मैं यहां डेटा साइंस कोर्स के बारे में जानना चाहता हूं।",
        "डेटा विज्ञान पाठ्यक्रम यहाँ।"
      ],
      "responses": [
        "हम पायथन, एसक्यूएल, मशीन लर्निंग, डीप लर्निंग, नेचुरल लैंग्वेज प्रोसेसिंग, डेटा साइंस के लिए कक्षाएं प्रदान करते हैं"
      ]
    },
    {
      "tag": "कैप्स्टोन परियोजना",
      "patterns": [
        "कैपस्टोन प्रोजेक्ट क्या है?",
        "कैप्स्टोन परियोजना ?",
        "कैपस्टोन प्रोजेक्ट के बारे में बताएं?"
      ],
      "responses": [
        "यह एक परियोजना है जिसे आपको अपने पाठ्यक्रम के अंत में शुरू करना है।"
      ]
    }, 
    {
      "tag": "एनएलपी",
      "patterns": [
        "एनएलपी क्या है ?",
        "एनएलपी?",
        "मुझे एनएलपी के बारे में बताओ?"
      ],
      "responses": [
        "यह प्राकृतिक भाषा प्रसंस्करण है"
      ]
    }, 
    {
      "tag": "ठीक है",
      "patterns": [
        "ठीक है",
        "ठीक है शुक्रिया"
      ],
      "responses": [
        "और कुछ?"
      ]
    }, 
     {
      "tag": "ठीक",
      "patterns": [
        "क्या हाल है?"
    
      ],
      "responses": [
        "मैं ठीक हूँ",
        "अच्छा, याचना के लिए शुक्रिया"
      ]
    }, 
     {
      "tag": "प्लेसमेंट",
      "patterns": [
        "नियुक्तियों के बारे में क्या?",
        "क्या आप नियुक्तियों की पेशकश करते हैं?"
      ],
      "responses": [
        "हाँ। हम 22 वर्षों से आईटी प्रशिक्षण में अनुभव को आगे बढ़ा रहे हैं। \nबुक माई शो का पहला कर्मचारी हमारा छात्र था।"
      ]
    }, 
      
    {
      "tag": "पाठ्यक्रम की अवधि",
      "patterns": [
        "कोर्स पूरा करने में कितना समय लगेगा?",
        "कोर्स की अवधि क्या है?",
        "कोर्स पूरा करने में कितना समय लगेगा?"
      ],
      "responses": [
        "प्रत्येक पाठ्यक्रम को पूरा करने में लगभग 2-3 महीने लगते हैं और पूर्ण डेटा विज्ञान पाठ्यक्रम की अवधि लगभग 10-12 महीने होती है जिसमें कैपस्टोन परियोजना शामिल होती है"
      ]
    },
    {
      "tag": "कक्षा",
      "patterns": [
        "कक्षा कब है?",
        "क्लास रोज है ?",
        "क्या हमें हर दिन क्लास के लिए आने की जरूरत है?"
      ],
      "responses": [
        "कक्षाएं सप्ताह में तीन बार आयोजित की जाती हैं। या तो एमडब्ल्यूएफ या टीटीएस"
      ]
    },
    {
      "tag": "फीस",
      "patterns": [
        "कोर्स की फीस कितनी है?",
        "कोर्स की फीस ?",
        "फीस?"
      ],
      "responses": [
        "यह इस बात पर निर्भर करता है कि आप डेटा इंजीनियरिंग (डेटा एनालिटिक्स)/या मशीन लर्निंग (एमएल) या डीप लर्निंग और एनएलपी के साथ संपूर्ण डेटा साइंस कर रहे हैं।"
      ]
    },
     {
      "tag": "प्लेसमेंट की गारंटी",
      "patterns": [
        "क्या आपके पास प्लेसमेंट गारंटी है?",
        "प्लेसमेंट गारंटी क्या है?",
        "प्लेसमेंट की गारंटी ?",
        "क्या प्लेसमेंट की गारंटी है?"
      ],
      "responses": [
        "गारंटी कंपनियों के साथ साक्षात्कार है। अंतत: आपको प्रश्न का उत्तर देना होगा"
      ]
    }, 
     {
      "tag": "पूर्वस्थापन सत्र",
      "patterns": [
        "प्लेसमेंट तैयारी सत्र के बारे में क्या है?",
        "प्लेसमेंट तैयारी सत्र?",
          ],
      "responses": [
        "हां, सेशन फॉर्म पर्सनैलिटी डेवलपमेंट से लेकर सॉफ्ट स्किल्स ट्रेनिंग आदि हैं."
      ]
    }, 
    {
      "tag": "कक्षा की अवधि",
      "patterns": [
        "एक सत्र कितने समय के लिए होता है?",
        "एक कक्षा कितने समय तक चलती है ?",
        "एक वर्ग कितना लंबा है ?",
        "एक वर्ग की अवधि क्या है?"

      ],
      "responses": [
        "एक क्लास की अवधि 2 घंटे है।"
      ]
    }
  ]
}

# %%
mrData = {
  "intents": [
    {
      "tag": "अभिवादन",
      "patterns": [
        "नमस्कार",
        "Hello,",
        "तुम्ही डेटा सायन्स कोर्स ऑफर करता का?"
      ],
      "responses": [
        "नमस्कार,",
        "नमस्कार, मी तुमच्यासाठी काय करू शकतो?",
        "नमस्कार, मी कशी मदत करू?",
        "होय आम्ही करू!"
      ]
    },
    {
     "tag":"डेटा विज्ञान",
     "patterns":["तुमच्याकडे डेटा सायन्स कोर्स आहे का?",
               "डेटा सायन्स कोर्स ?"],
     "responses":["होय आम्ही करू!"]
    },
    {
      "tag": "निरोप",
      "patterns": ["बाय", "पुन्हा भेटू", "निरोप"],
      "responses": [
        "नंतर भेटू, भेट दिल्याबद्दल धन्यवाद",
        "तुमचा दिवस चांगला जावो",
        "बाय! लवकरच परत या."
      ]
    },
    {
      "tag": "धन्यवाद",
      "patterns": ["धन्यवाद", "धन्यवाद", "ते उपयुक्त आहे", "खूप खूप धन्यवाद!"],
      "responses": ["मदत करण्यात आनंद झाला!", "कधीही!", "माझा आनंद"]
    },
    {
      "tag": "अभ्यासक्रम",
      "patterns": [
        "तुमच्याकडे सर्व अभ्यासक्रम कोणते आहेत?",
        "किती अभ्यासक्रम?"
        "मला येथे डेटा सायन्स कोर्सेसबद्दल चौकशी करायची आहे.",
        "मला येथे डेटा सायन्स अभ्यासक्रमांबद्दल विचारायचे आहे",
        "मला येथे डेटा सायन्स अभ्यासक्रमांबद्दल जाणून घ्यायचे आहे.",
        "डेटा विज्ञान अभ्यासक्रम येथे."
      ],
      "responses": [
        "आम्ही पायथन, एसक्यूएल, मशीन लर्निंग, डीप लर्निंग, नॅचरल लँग्वेज प्रोसेसिंग, डेटा सायन्सचे वर्ग प्रदान करतो"
      ]
    },
    {
      "tag": "कॅपस्टोन प्रकल्प",
      "patterns": [
        "कॅपस्टोन प्रकल्प काय आहे?",
        "कॅपस्टोन प्रकल्प ?",
        "मला कॅपस्टोन प्रकल्पाबद्दल सांगा ?"
      ],
      "responses": [
        "हा एक प्रकल्प आहे जो तुम्हाला तुमच्या कोर्सच्या शेवटी घ्यावा लागेल."
      ]
    }, 
    {
      "tag": "एनएलपी",
      "patterns": [
        "एनएलपी म्हणजे काय ?",
        "एनएलप ?",
        "मला nlp बद्दल सांगा ?"
      ],
      "responses": [
        "ही नैसर्गिक भाषा प्रक्रिया आहे"
      ]
    }, 
    {
      "tag": "ठीक आहे",
      "patterns": [
        "ठीक आहे",
        "ठीक आहे धन्यावाद"
      ],
      "responses": [
        "अजून काही?"
      ]
    }, 
     {
      "tag": "ठीक",
      "patterns": [
        "तू कसा आहेस?"
    
      ],
      "responses": [
        "मी चांगला आहे",
        "छान, विचारल्याबद्दल धन्यवाद"
      ]
    }, 
     {
      "tag": "प्लेसमेंट",
      "patterns": [
        "प्लेसमेंटबद्दल काय ?",
        "तुम्ही प्लेसमेंट ऑफर करता का? ?"
      ],
      "responses": [
        "होय. आम्ही 22 वर्षांपासून आयटी प्रशिक्षणाचा अनुभव पुढे नेत आहोत. \BBook my show प्रथम कर्मचारी तुमचा विद्यार्थी होता.\nआम्ही अलीकडेच MNC च्या नावाप्रमाणे विद्यार्थ्यांना स्थान दिले आहे. "
      ]
    }, 
      
    {
      "tag": "अर्थातच कालावधी",
      "patterns": [
        "अभ्यासक्रम पूर्ण करण्यासाठी किती वेळ लागेल ?",
        "अभ्यासक्रमाचा कालावधी किती आहे ?",
        "अभ्यासक्रम पूर्ण करण्यासाठी किती वेळ लागेल?"
      ],
      "responses": [
        "प्रत्येक कोर्स पूर्ण करण्यासाठी सुमारे 2-3 महिने लागतात आणि संपूर्ण डेटा सायन्स कोर्सचा कालावधी अंदाजे 10-12 महिने असतो ज्यामध्ये कॅपस्टोन प्रकल्प समाविष्ट असतो" ]
    },
    {
      "tag": "वर्ग",
      "patterns": [
        "वर्ग कधी आहे ?",
        "रोजचा वर्ग आहे ?",
        "आम्हाला दररोज वर्गासाठी यावे लागेल का? ?"
      ],
      "responses": [
        "वर्ग आठवड्यातून तीन वेळा आयोजित केले जातात. एकतर MWF किंवा TTS"
      ]
    },
    {
      "tag": "फी",
      "patterns": [
        "कोर्सची फी किती आहे?",
        "कोर्सची फी?",
        "फी ?"
      ],
      "responses": [
        "तुम्ही डेटा इंजिनीअरिंग (डेटा अॅनालिटिक्स)/किंवा मशीन लर्निंग (एमएल) करत आहात की डीप लर्निंग आणि एनएलपीसह संपूर्ण डेटा सायन्स करत आहात यावर ते अवलंबून आहे."
      ]
    },
     {
      "tag": "प्लेसमेंट हमी",
      "patterns": [
        "तुमच्याकडे प्लेसमेंटची हमी आहे का?",
        "प्लेसमेंट हमी काय आहे ?",
        "प्लेसमेंट हम ?",
        "प्लेसमेंटची हमी आहे का??"
      ],
      "responses": [
        "Tहमी कंपन्यांच्या मुलाखतींसाठी आहे. शेवटी तुम्हाला प्रश्नाचे उत्तर द्यावे लागेल"
      ]
    }, 
     {
      "tag": "प्रीप्लेसमेंट सत्रे",
      "patterns": [
        "प्लेसमेंट तयारी सत्रांबद्दल काय आहे?",
        "प्लेसमेंट तयारी सत्र ?",
          ],
      "responses": [
        "होय व्यक्तिमत्व विकास ते सॉफ्ट स्किल ट्रेनिंग इत्यादी सत्र आहेत."
      ]
    }, 
    {
      "tag": "वर्ग कालावधी",
      "patterns": [
        "एका सत्रासाठी किती वेळ आहे ?",
        "एक वर्ग किती काळ चालतो ?",
        "एक वर्ग किती लांब आहे ?",
        "एका वर्गाचा कालावधी किती आहे ?"

      ],
      "responses": [
        "एका वर्गाचा कालावधी २ तासांचा असतो."
      ]
    }
  ]
}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []

mrClasses = []
mrWords = []
documentm = []
documentr = []

hiClasses = []
hiWords = []
documenth = []
documenti = []

# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["intents"]:
    for pattern in intent["patterns"]:
        ourTokens = nltk.word_tokenize(pattern)
        newWords.extend(ourTokens)
        documentX.append(pattern)
        documentY.append(intent["tag"])
    
    
    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

for intent in mrData["intents"]:
    for pattern in intent["patterns"]:
        mrTokens = nltk.word_tokenize(pattern)
        mrWords.extend(mrTokens)
        documentm.append(pattern)
        documentr.append(intent["tag"])
    
    
    if intent["tag"] not in mrClasses:# add unexisting tags to their respective classes
        mrClasses.append(intent["tag"])

for intent in hiData["intents"]:
    for pattern in intent["patterns"]:
        hiTokens = nltk.word_tokenize(pattern)
        hiWords.extend(hiTokens)
        documenth.append(pattern)
        documenti.append(intent["tag"])
    
    
    if intent["tag"] not in hiClasses:# add unexisting tags to their respective classes
        hiClasses.append(intent["tag"])

hiWords = [lm.lemmatize(word.lower()) for word in hiWords if word not in string.punctuation] # set words to lowercase if not in punctuation
hiWords = sorted(set(hiWords))# sorting words
hiClasses = sorted(set(hiClasses))# sorting classes

mrWords = [lm.lemmatize(word.lower()) for word in mrWords if word not in string.punctuation] # set words to lowercase if not in punctuation
mrWords = sorted(set(mrWords))# sorting words
mrClasses = sorted(set(mrClasses))# sorting classes

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)

hitrainingData = [] # training list array
hiEmpty = [0] * len(hiClasses)

mrtrainingData = [] # training list array
mrEmpty = [0] * len(mrClasses)

# BOW model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)
    
    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

for idx, doc in enumerate(documentm):
    mrbagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in mrWords:
        mrbagOfwords.append(1) if word in text else mrbagOfwords.append(0)
    
    mroutputRow = list(mrEmpty)
    mroutputRow[mrClasses.index(documentr[idx])] = 1
    mrtrainingData.append([mrbagOfwords, mroutputRow])

random.shuffle(mrtrainingData)
mrtrainingData = num.array(mrtrainingData, dtype=object)# coverting our data into an array afterv shuffling

for idx, doc in enumerate(documenth):
    hibagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in hiWords:
        hibagOfwords.append(1) if word in text else hibagOfwords.append(0)
    
    hioutputRow = list(hiEmpty)
    hioutputRow[hiClasses.index(documenti[idx])] = 1
    hitrainingData.append([hibagOfwords, hioutputRow])

random.shuffle(hitrainingData)
hitrainingData = num.array(hitrainingData, dtype=object)# coverting our data into an array afterv shuffling

h = num.array(list(hitrainingData[:, 0]))# first trainig phase
i = num.array(list(hitrainingData[:, 1]))# second training phase

m = num.array(list(mrtrainingData[:, 0]))# first trainig phase
r = num.array(list(mrtrainingData[:, 1]))# second training phase

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
# defining some parameters
iShape = (len(x[0]),)
oShape = len(y[0])

hiShape = (len(h[0]),)
hioShape = len(i[0])

mrShape = (len(m[0]),)
mroShape = len(r[0])

# the deep learning model
ourNewModel = Sequential()
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
ourNewModel.add(Dropout(0.5))
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
md = tensorF.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
print(ourNewModel.summary())
ourNewModel.fit(x, y, epochs=200, verbose=1)

hiourNewModel = Sequential()
hiourNewModel.add(Dense(128, input_shape=hiShape, activation="relu"))
hiourNewModel.add(Dropout(0.5))
hiourNewModel.add(Dense(64, activation="relu"))
hiourNewModel.add(Dropout(0.3))
hiourNewModel.add(Dense(hioShape, activation = "softmax"))
himd = tensorF.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
hiourNewModel.compile(loss='categorical_crossentropy',
              optimizer=himd,
              metrics=["accuracy"])
print(hiourNewModel.summary())
hiourNewModel.fit(h, i, epochs=200, verbose=1)

# the deep learning model
mrourNewModel = Sequential()
mrourNewModel.add(Dense(128, input_shape=mrShape, activation="relu"))
mrourNewModel.add(Dropout(0.5))
mrourNewModel.add(Dense(64, activation="relu"))
mrourNewModel.add(Dropout(0.3))
mrourNewModel.add(Dense(mroShape, activation = "softmax"))
mrmd = tensorF.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
mrourNewModel.compile(loss='categorical_crossentropy',
              optimizer=mrmd,
              metrics=["accuracy"])
print(mrourNewModel.summary())
mrourNewModel.fit(m, r, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               9344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
# ...
# Total params: 18,640
# Trainable params: 18,640
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 2/2 [==============================] - 1s 8ms/step - loss: 2.8419 - accuracy: 0.0851
# Epoch 2/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.6862 - accuracy: 0.1277
# Epoch 3/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3485 - accuracy: 0.3191
# Epoch 4/200
# ...

# %%
def ourText(text): 
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab): 
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bagOwords[idx] = 1
  return num.array(bagOwords)

def pred_class(text, vocab, labels): 
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson): 
  tag = firstlist[0]
  listOfIntents = fJson["intents"]
  for i in listOfIntents: 
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
def hiourText(text): 
  hinewtkns = nltk.word_tokenize(text)
  hinewtkns = [lm.lemmatize(word) for word in hinewtkns]
  return hinewtkns

def hiwordBag(text, vocab): 
  hinewtkns = hiourText(text)
  hibagOwords = [0] * len(vocab)
  for w in hinewtkns: 
    for idx, word in enumerate(vocab):
      if word == w: 
        hibagOwords[idx] = 1
  return num.array(hibagOwords)

def hipred_class(text, vocab, labels): 
  hibagOwords = hiwordBag(text, vocab)
  hiourResult = hiourNewModel.predict(num.array([hibagOwords]))[0]
  hinewThresh = 0.2
  hiyp = [[idx, res] for idx, res in enumerate(hiourResult) if res > hinewThresh]

  hiyp.sort(key=lambda x: x[1], reverse=True)
  hinewList = []
  for r in hiyp:
    hinewList.append(labels[r[0]])
  return hinewList

def higetRes(firstlist, fJson): 
  hitag = firstlist[0]
  hilistOfIntents = fJson["intents"]
  for i in hilistOfIntents: 
    if i["tag"] == hitag:
      hiourResult = random.choice(i["responses"])
      break
  return hiourResult

# %%
def mrourText(text): 
  mrnewtkns = nltk.word_tokenize(text)
  mrnewtkns = [lm.lemmatize(word) for word in mrnewtkns]
  return mrnewtkns

def mrwordBag(text, vocab): 
  mrnewtkns = mrourText(text)
  mrbagOwords = [0] * len(vocab)
  for w in mrnewtkns: 
    for idx, word in enumerate(vocab):
      if word == w: 
        mrbagOwords[idx] = 1
  return num.array(mrbagOwords)

def mrpred_class(text, vocab, labels): 
  mrbagOwords = mrwordBag(text, vocab)
  mrourResult = mrourNewModel.predict(num.array([mrbagOwords]))[0]
  mrnewThresh = 0.2
  mryp = [[idx, res] for idx, res in enumerate(mrourResult) if res > mrnewThresh]

  mryp.sort(key=lambda x: x[1], reverse=True)
  mrnewList = []
  for r in mryp:
    mrnewList.append(labels[r[0]])
  return mrnewList

def mrgetRes(firstlist, fJson): 
  mrtag = firstlist[0]
  mrlistOfIntents = fJson["intents"]
  for i in mrlistOfIntents: 
    if i["tag"] == mrtag:
      mrourResult = random.choice(i["responses"])
      break
  return mrourResult

# %%
from langdetect import detect
x = detect(input())

if x == "mr":
  mrflag  = True
  print("नमस्ते")
  while (mrflag==True):
    mrnewMessage = input("")
    mrintents = mrpred_class(mrnewMessage, mrWords, mrClasses)
    mrourResult = mrgetRes(mrintents, mrData)
    print(mrourResult)
    if(mrnewMessage!='निरोप'):
      if mrnewMessage=='धन्यवाद':
        mrflag=False
        print("ROBO:धन्यवाद..")
    else:
      mrflag=False
      print("ROBO: भेट दिल्याबद्दल धन्यवाद ..")
      
elif x == "en":
    flag  = True
    print("Hello,My name is Robo.")
    while (flag==True):
        newMessage = input("")
        intents = pred_class(newMessage, newWords, ourClasses)
        ourResult = getRes(intents, ourData)
        print(ourResult)
        if(newMessage!='bye'):
              if(newMessage=='thanks' or newMessage=='thank you' ):
                flag=False
                print("ROBO: You are welcome..")
        else:
            flag=False
            print("ROBO: Bye! take care..")

elif x == "hi":
  hiflag  = True
  print("नमस्ते")
  while (hiflag==True):
    hinewMessage = input("")
    hiintents = hipred_class(hinewMessage, hiWords, hiClasses)
    hiourResult = higetRes(hiintents, hiData)
    print(hiourResult)
    if(hinewMessage!='अलविदा'):
      if hinewMessage=='धन्यवाद':
        hiflag=False
        print("ROBO:धन्यवाद..")
    else:
      hiflag=False
      print("ROBO: अलविद..")
else:
    print("I don't understand this language")
# Out:
# hi nice to meet you
# Hello,My name is Robo.
# data science
# 1/1 [==============================] - 0s 56ms/step
# Yes,we do!
# fees
# 1/1 [==============================] - 0s 19ms/step
# It depends on whether you are doing Data Engineering(data Analytics)/or Machine Learning(ML) or the entire Data Science with deep Learning and NLP
# what all courses
# 1/1 [==============================] - 0s 17ms/step
# We provide classes for Python, SQL, Machine Learning, Deep Learning, Natural Language Processing,Data science
# डेटा विज्ञान
# 1/1 [==============================] - 0s 19ms/step
# See you later, thanks for visiting
# डेटा विज्ञान
# 1/1 [==============================] - 0s 17ms/step
# Bye! Come back again soon.
# कैप्स्टोन परियोजना
# 1/1 [==============================] - 0s 18ms/step
# See you later, thanks for visiting
# bye
# 1/1 [==============================] - 0s 18ms/step
# See you later, thanks for visiting
# ROBO: Bye! take care..
